# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

os.environ["OPENROUTER_API_KEY"] = "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"

# %%
from crewai import LLM

llm = LLM(

    model = "openrouter/mistralai/mistral-7b-instruct",
    temperature=0.1
)

# llm.call("Who invented transcendental meditation.")


try:
    response = llm.call("Who invented transcendental meditation.")
    print("LLM Test Response:", response)
    
except Exception as e:
    print(f"Error: {e}")
    print("\nTo fix this error:")
    print("1. Get your API key from: https://openrouter.ai/keys")
    print("2. Replace 'your_openrouter_api_key_here' with your actual API key")
    print("3. Or create a .env file with: OPENROUTER_API_KEY=your_actual_key")
# Out:
# LLM Test Response:  Transcendental Meditation (TM) was developed by Maharishi Mahesh Yogi, an Indian guru who popularized the practice in the West during the mid-20th century. He was born as Mahesh Prasad Varma in Uttar Pradesh, India, in 1917. Maharishi Mahesh Yogi studied under several gurus before developing his own approach to meditation, which he began teaching in the 1950s. He gained widespread fame in the 1960s and 1970s when he attracted a large following among celebrities and influential figures, including the Beatles. Maharishi Mahesh Yogi passed away in 2008.
# c:\Users\godwi\OneDrive\Desktop\mail_writer_crewai\.venv\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content=' Transce...one, 'reasoning': None}), input_type=Message])
# ...

# %%
original_email = """

hey team, just wanted to tell u that the demo is kind of ready. but there's still stuff left.
Maybe we can show what we have and say rest is WIP
Let me kknow what u think. thanks

"""

from crewai.tools import BaseTool

class ReplaceJargonsTools(BaseTool):
    name: str = "Replace Jargons"
    description: str = "Replace jargons with more specific terms"

    def _run(self,email: str) -> str:

        replacement = {

            "PRX" : "Project Phoneix (internal AI revamp project)",
            "TAS" : "technical architecture stack",
            "DBX" : "client database cluster",
            "SDS" : "Smart Data Syncer",
            "SYNCBOT" : "internal standup assistant bot",
            "WIP" : "work in progress",
            "PDC" : "proof of concept",
            "ping" : "reach out"

        }

        suggestions = []

        email_lower = email.lower()

        for jargon, replacement in replacement.items():
            if jargon.lower() in email_lower:
                suggestions.append(f"consider replacing {jargon} with {replacement}")

        
        return "\n".join(suggestions) if suggestions else "No jargon or internal abbreviations"


jt = ReplaceJargonsTools()
jt.run(original_email)
# Out:
# Using Tool: Replace Jargons
# 'consider replacing WIP with in progress'

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(

    role="Email Assistant Agent",
    goal="Improve emails and makke them sounds professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    tools = [jt],
    verbose=True,
    llm=llm
)

# %%
from asyncio import tasks


email_task = Task(

    description = f"""Tae the following rough email and rewrite it into a professional and polished version.
    
    Expand abbreviations:
    
    '''{original_email}'''""",

    agent = email_assistant,
    expected_output = "A professional written email with proper formatting and content."
)


crew = Crew(

    agents = {email_assistant},
    tasks = [email_task],
    verbose = True,
)


result = crew.kickoff()

print(result)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: e3069747-f5c1-4baa-a950-a47be46142c1                                   │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: ddb819d4-5de4-49dc-bf56-677eee9537ee
#     Status: Executing Task...
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# ...
